# %% [markdown]
# # **Regular Expressions in Python**
#
# ## Course Description
#
# As a data scientist, you will encounter many situations where you will need to extract key information from huge corpora of text, clean messy data containing strings, or detect and match patterns to find useful words. All of these situations are part of text mining and are an important step before applying machine learning algorithms. This course will take you through understanding compelling concepts about string manipulation and regular expressions. You will learn how to split strings, join them back together, interpolate them, as well as detect, extract, replace, and match strings using regular expressions. On the journey to master these skills, you will work with datasets containing movie reviews or streamed tweets that can be used to determine opinion, as well as with raw text scraped from the web.

# %% [markdown]
# ## Content
#
# 1. Basic Concepts of String Manipulation
# - string index
# - String operation
#
#     - .lower()
#
#     - .strip()
#
#     - .split()
#
#     - .rstrip()
#
#     - .join()
# - lines split
#     - .splitlines()
#
# - Finding and relacing substrings
#
#     - .find(): 'string.find(**substring**,start,end)'
#
#     - .index(): 'string.index(**substring**,start,end)'
#
#     - .count(): 'string.count(**substring**,start,end)'
#
#     - .replace(): 'string.replace(**old**,**new**,count)' count = number of time of replace
#
#
# 2. Formatting Strings
#
# 3. Regular Expressions for Pattern Matching
#
# 4. Advanced Regular Expression Concepts

# %% [markdown]
# ## 1. Basic Concepts of String Manipulation
#
# Start your journey into the regular expression world! From slicing and concatenating, adjusting the case, removing spaces, to finding and replacing strings. You will learn how to master basic operation for string manipulation using a movie review dataset.

# %% [markdown]
# [1.1] Subset the string by index
#
# --------
#
# - Extract the substring from the 12th to the 30th character from the variable movie which corresponds to the movie title. Store it in the variable movie_title.
# - Get the palindrome by reversing the string contained in movie_title.
# - Complete the code to print out the movie_title if it is a palindrome.

# %%
movie = 'oh my God! desserts I stressed was an ugly movie'

# Get the word
movie_title = movie[11:30]

# Obtain the palindrome
palindrome = movie_title[::-1] # Reversing the 'movie_title' by '-1'

# Print the word if it's a palindrome
if movie_title == palindrome:
	print(movie_title)
# Out:
# desserts I stressed

# %% [markdown]
# [1.2] String operation

# %% [markdown]
# ----------------------
#
# - .lower()
# - .strip()
# - .split()

# %%
movie = '$I supposed that coming from MTV Films I should expect no less$'

# Convert to lowercase and print the result
movie_lower = movie.lower()
print('Convert to lowercase and print the result:\n',movie_lower,'\n')

# Remove specified character and print the result
movie_no_sign = movie_lower.strip("$")
print('Remove specified character and print the result:\n',movie_no_sign,'\n')

# Split the string into substrings and print the result
movie_split = movie_no_sign.split()
print('Split the string into substrings and print the result:\n',movie_split,'\n')

# Select root word and print the result
word_root = movie_split[1][:]
print('The second element of word_root is :', word_root)
# Out:
# Convert to lowercase and print the result:
#  $i supposed that coming from mtv films i should expect no less$
#
# Remove specified character and print the result:
#  i supposed that coming from mtv films i should expect no less
#
# Split the string into substrings and print the result:
#  ['i', 'supposed', 'that', 'coming', 'from', 'mtv', 'films', 'i', 'should', 'expect', 'no', 'less']
#
# The second element of word_root is : supposed

# %% [markdown]
# ------
#
# - .rstrip()
# - .join()

# %%
movie = 'the film,however,is all good<\\i>'

# Remove tags happening at the end and print results
movie_tag = movie.rstrip("<\i>")
print('Remove tags happening at the end and print results:\n',movie_tag,'\n')

# Split the string using commas and print results
movie_no_comma = movie_tag.split(",")
print('Split the string using commas and print results:\n',movie_no_comma,'\n')

# Join back together and print results
movie_join = ' '.join(movie_no_comma)
print('Join back together and print results:\n',movie_join)
# Out:
# Remove tags happening at the end and print results:
#  the film,however,is all good
#
# Split the string using commas and print results:
#  ['the film', 'however', 'is all good']
#
# Join back together and print results:
#  the film however is all good

# %% [markdown]
# [1.3] Split lines or split the line?

# %%
file = 'mtv films election, a high school comedy, is a current example\nfrom there, director steven spielberg wastes no time, taking us into the water on a midnight swim'

print('original:\n', file,'\n')

# Split string at line boundaries
file_split = file.splitlines()

# Print file_split
print('split by lines:\n',file_split,'\n')

# Complete for-loop to split by commas

print('split by lines and commas:')

for substring in file_split:
    substring_split = substring.split(',')
    print(substring_split)
# Out:
# original:
#  mtv films election, a high school comedy, is a current example
# from there, director steven spielberg wastes no time, taking us into the water on a midnight swim
#
# split by lines:
#  ['mtv films election, a high school comedy, is a current example', 'from there, director steven spielberg wastes no time, taking us into the water on a midnight swim']
#
# split by lines and commas:
# ['mtv films election', ' a high school comedy', ' is a current example']
# ['from there', ' director steven spielberg wastes no time', ' taking us into the water on a midnight swim']

# %% [markdown]
# [1.4] Finding and relacing substrings
#
# - .find(): 'string.find(**substring**,start,end)'
#
# - .index(): 'string.index(**substring**,start,end)'
#
# - .count(): 'string.count(**substring**,start,end)'
#
# - .replace(): 'string.replace(**old**,**new**,count)' count = number of time of replace

# %% [markdown]
# --------------------
#
# Finding a substring
#
# --------------------
#
# - Find if the substring actor occurs between the characters with index 37 and 41 inclusive. If it is not detected, print the statement Word not found.
# - Replace actor actor with the substring actor if actor occurs only two repeated times.
# - Replace actor actor actor with the substring actor if actor appears three repeated times.

# %%
movies = ["it's clear that he's passionate about his beliefs , and that he's not just a punk looking for an excuse to beat people up .",
"I believe you I always said that the actor actor actor is amazing in every movie he has played",
"it's astonishing how frightening the actor actor norton looks with a shaved head and a swastika on his chest."]

for movie in movies:
  	# If actor is not found between character 37 and 41 inclusive
    # Print word not found
    if movie.find("actor", 37, 42) == -1:
        print("Word not found")
    # Count occurrences and replace two with one
    elif movie.count("actor") == 2:  
        print(movie.replace("actor actor", "actor"))
    else:
        # Replace three occurrences with one
        print(movie.replace("actor actor actor", "actor"))
# Out:
# Word not found
# I believe you I always said that the actor is amazing in every movie he has played
# it's astonishing how frightening the actor norton looks with a shaved head and a swastika on his chest.

# %% [markdown]
# - Find the index where money occurs between characters with index 12 and 50. If not found, it should raise an error.

# %%
movies = ["heck , jackie doesn't even have enough money for a haircut , looks like , much less a personal hairstylist .",
"in condor , chan plays the same character he's always played , himself , a mixture of bruce lee and tim allen , a master of both kung-fu and slapstick-fu ."]


for movie in movies:
  try:
    # Find the first occurrence of word
  	print(movie.index('money',12, 51))
  except ValueError:
    print("substring not found")
# Out:
# 39
# substring not found

# %% [markdown]
# Replacing
#
# ----------------------
#
# - Replace the substring isn't with the word is.
# - Replace the substring important with the word insignificant.
# - Print out the result contained in the variable movies_antonym.

# %%
movies = "the rest of the story isn't important because all it does is serve as a mere backdrop for the two stars to share the screen ."

# Replace negations 
movies_no_negation = movies.replace("isn't", "is")

# Replace important
movies_antonym = movies_no_negation.replace("important", "insignificant")

# Print out
print(movies_antonym)
# Out:
# the rest of the story is insignificant because all it does is serve as a mere backdrop for the two stars to share the screen .

# %% [markdown]
# ## 2. Formatting Strings
#
# Following your journey, you will learn the main approaches that can be used to format or interpolate strings in python using a dataset containing information scraped from the web. You will explore the advantages and disadvantages of using positional formatting, embedding expressing inside string constants, and using the Template class.

# %% [markdown]
# [2.1] Positional formatting

# %% [markdown]
# The postional formatting by **ordering**
#
# --------------------
#
# - Assign the substrings going from the 4th to the 19th character inclusive, and from the 22nd to the 44th character inclusive of wikipedia_article to the variables first_pos and second_pos, respectively. Adjust the strings to be lowercase.
# - Define a string with the text "The tool is used in" adding placeholders after the word tool and the word in for future positional formatting. Append it to the list my_list.
# - Define a string with the text "The tool is used in" adding placeholders after the word tool and in but reorder them so the second argument passed to the method will replace the first placeholder. Append to the list my_list.
# - Complete the for-loop so that it uses the .format() method and the variables first_pos and second_pos to print out every string in my_list.

# %%
my_list = []

wikipedia_article = 'In computer science, artificial intelligence (AI), sometimes called machine intelligence, is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals.'

# Assign the substrings to the variables
first_pos = wikipedia_article[3:19].lower()
second_pos = wikipedia_article[21:44].lower()

# Define string with placeholders 
my_list.append("The tool {} is used in {}")

# Define string with rearranged placeholders
my_list.append("The tool {1} is used in {0}")

print('Defined 2 different order with the positional formate:\n','without ordering:\n',my_list[0],'\n','with ordering:\n',my_list[1],'\n')

# Use format to print strings
for my_string in my_list:
  	print(f'formate :" {my_string} " will like:\n',my_string.format(first_pos, second_pos),'\n')
# Out:
# Defined 2 different order with the positional formate:
#  without ordering:
#  The tool {} is used in {}
#  with ordering:
#  The tool {1} is used in {0}
#
# formate :" The tool {} is used in {} " will like:
#  The tool computer science is used in artificial intelligence
#
# formate :" The tool {1} is used in {0} " will like:
#  The tool artificial intelligence is used in computer science

# %% [markdown]
# The postional formatting by **naming**
#
# ------------------------
#
# - Create a dictionary assigning the first and second element appearing in the list courses to the keys "field" and "tool" respectively.
# - Complete the placeholders accessing inside to the elements linked with the keys field and tool in the dictionary data.
# - Print out the resulting message using the .format() method, passing the plan dictionary to replace the data placeholders.

# %%
courses = ['artificial intelligence', 'neural networks']

# Create a dictionary
plan = {
  		"field": courses[0],
        "tool": courses[1]
        }

# Complete the placeholders accessing elements of field and tool keys in the data dictionary
my_message = "If you are interested in {data[field]}, you can take the course related to {data[tool]}"

# Use the plan dictionary to replace placeholders
print(my_message.format(data=plan))
# Out:
# If you are interested in artificial intelligence, you can take the course related to neural networks

# %% [markdown]
# The positional formatting of the **Datetime**
# ---------------
#
# It's lunch time and you are talking with some of your colleagues. They comment that they feel that every morning someone should send them a reminder of what day it is so they can check in the calendar what their assignments are for that day.
#
# You want to help out and decide to write a small script that takes the date and time of the day so that every morning, a message is sent to your colleagues. You can use the module datetime along with named placeholders to achieve your goal.
#
# The date should be expressed as Month day, year, e.g. April 16, 2019 and the time as hh:mm, e.g. 16:30.
#
# You write down some specifiers to help you: %d(day), %B (monthname), %m (monthnumber), %Y(year), %H (hour) and %M(minutes)
#
# --------------------
#
# - Import the function datetime from the module datetime .
# - Obtain the date of today and assign it to the variable get_date.
# - Complete the string message by adding to the placeholders named today and the format specifiers to format the date as month_name day, year and time as hour:minutes.

# %%
# Import datetime 
from datetime import datetime

# Assign date to get_date
get_date = datetime.now()

print('The time is:\n',get_date,'\n')

# Add named placeholders with format specifiers
message = "Good morning. Today is {today:%B %d, %Y}. It's {today:%H:%M} ... time to work!"

print('The formate is:\n',message,'\n')

# Use the format method replacing the placeholder with get_date
print(f'The replaced result is:\n {message.format(today=get_date)}')
# Out:
# The time is:
#  2022-12-09 22:22:57.777141
#
# The formate is:
#  Good morning. Today is {today:%B %d, %Y}. It's {today:%H:%M} ... time to work!
#
# The replaced result is:
#  Good morning. Today is December 09, 2022. It's 22:22 ... time to work!

# %% [markdown]
# [2.2]The Formatted string literal (**f-strings formatting**)

# %%
from IPython.display import Image

Image("type conversion.png",width = 800,height = 500)

# %%
Image("format specifiers.png",width = 800,height = 500)

# %%
Image("format specifiers 2.png",width = 600,height = 500)

# %%
Image("index lookup.png",width = 600,height = 500)

# %% [markdown]
# ---------------
#
# Literally formatting with **f-string**
#
# ---------------
#
# - Complete the f-string to include the variable field1 with quotes and the variable fact1 as a digit.
# - Complete the f-string to include the variable fact2 using exponential notation, and the variable field2.
# - Complete the f-string to include field3, fact3 rounded to 2 decimals, and fact4 rounded to one decimal.

# %%
field1 = 'sexiest job'
fact1 = 21

# Complete the f-string
print('the variable field1 with quotes and the variable fact1 as a digit:\n',f"Data science is considered '{field1}' in the {fact1}st century",'\n')


fact2 = 2500000000000000000
field2 = 'data is produced daily'

# Complete the f-string
print('the variable fact2 using exponential notation, and the variable field2:\n',f"About {fact2:.1e} of {field2} in the world",'\n')


field3='Individuals'
fact3=72.41415415151
fact4=1.09

# Complete the f-string
print('field3, fact3 rounded to 2 decimals, and fact4 rounded to one decimal.:\n',f"{field3} create around {fact3:.2f}% of the data but only {fact4:.1f}% is analyzed",'\n')
# Out:
# the variable field1 with quotes and the variable fact1 as a digit:
#  Data science is considered 'sexiest job' in the 21st century
#
# the variable fact2 using exponential notation, and the variable field2:
#  About 2.5e+18 of data is produced daily in the world
#
# field3, fact3 rounded to 2 decimals, and fact4 rounded to one decimal.:
#  Individuals create around 72.41% of the data but only 1.1% is analyzed

# %% [markdown]
# ---------------
# Embed the function in **f-string**
#
# ----------------
#
# Now you know that f-strings allow you to evaluate expressions where they appear and include function and method calls. You decide to use them in a project where you analyze 120 tweets to check if they include links to different news. In that way, you expect the code to be cleaner and more readable.
#
# The variables number1, number2,string1, and list_links have already been pre-loaded.
#
# -------------------
#
# - Inside the f-string, include number1,number2 and the result of dividing number1 by number2 rounded to one decimal.
# - Inside the f-string, use .replace() to replace the substring https with an empty substring in string1.
# - Inside the f-string, get list_links length, multiply it by 100 and divide it by 120. Round the result to two decimals.

# %%
number1 = 120
number2= 7
string1 = 'httpswww.datacamp.com'
list_links = ['www.news.com',
 'www.google.com',
 'www.yahoo.com',
 'www.bbc.com',
 'www.msn.com',
 'www.facebook.com',
 'www.news.google.com']

 # Include both variables and the result of dividing them 
print('Include both variables and the result of dividing them:\n',f"{number1} tweets were downloaded in {number2} minutes indicating a speed of {number1/number2:.1f} tweets per min",'\n')

# Replace the substring https by an empty string
print('Replace the substring https by an empty string:\n',f"{string1.replace('https', '')}",'\n')

# Divide the length of list by 120 rounded to two decimals
print('Divide the length of list by 120 rounded to two decimals:\n',f"Only {len(list_links)*100/120:.2f}% of the posts contain links")
# Out:
# Include both variables and the result of dividing them:
#  120 tweets were downloaded in 7 minutes indicating a speed of 17.1 tweets per min
#
# Replace the substring https by an empty string:
#  www.datacamp.com
#
# Divide the length of list by 120 rounded to two decimals:
#  Only 5.83% of the posts contain links

# %% [markdown]
# ------------
#
# Handle datetime in **f-string**
#
# -----------
#
# Lastly, you want to rewrite an old real estate prediction project. At the time, you obtained historical information about house prices and used it to make a prediction on future values.
#
# The date was in the datetime format: datetime.datetime(1990, 3, 17) but to print it out, you format it as 3-17-1990. You also remember that you defined a dictionary for each neighborhood. Now, you believe that you can handle both type of data better with f-strings.
#
# ----------------
#
# - Inside the f-string, access the values of the keys price and date in **east** dictionary. Format the date to month-day-year.
# - Inside the f-string, access the values of the keys price and date in **west** dictionary. Format the date to month-day-year.

# %%
import datetime

east = {'date': datetime.datetime(2007, 4, 20, 0, 0), 'price': 1232443}
west = {'date': datetime.datetime(2006, 5, 26, 0, 0), 'price': 1432673}

# Access values of date and price in east dictionary
print(f"The price for a house in the east neighborhood was ${west['price']} in {west['date']:%m-%d-%Y}",'\n')

# Access values of date and price in west dictionary
print(f"The price for a house in the west neighborhood was ${west['price']} in {west['date']:%m-%d-%Y}",'\n')
# Out:
# The price for a house in the east neighborhood was $1432673 in 05-26-2006
#
# The price for a house in the west neighborhood was $1432673 in 05-26-2006

# %% [markdown]
# [2.3]Template string

# %%
Image("template string.png",width = 500,height = 300)

# %% [markdown]
# ## 3. Regular Expressions for Pattern Matching
#
# In this key chapter, you will learn to understand the basic concepts of regular expression syntax. Using a real dataset with tweets meant for sentiment analysis, you will learn how to apply pattern matching using normal and special characters, and greedy and lazy quantifiers.
#
# -------------
#
# **The metacharacters**:
#
# - \d: digit
# - \D: Non-digit
# - \w: word character
# - \W: non-word character
# - \s: whitespace
# - \S: Non-whitespace
#
#         ***One metacharacter represent one element***
#
# ----------------
#
# **The functions:**
#
# - re.findall(r"regex",string)
# - re.split(r"regex",string)
# - re.sub(r"regex",replacement,string)

# %% [markdown]
# -------------
#
# Find the "@robot***X***"
#
# --------------
#
# - Import the re module.
# - Write a regex that matches the user mentions that starts with @ and follows the pattern, e.g. @robot3!.
# - Find all the matches of the pattern in the sentiment_analysis variable.

# %%
# Import the re module
import re
sentiment_analysis = '@robot9! @robot4& I have a good feeling that the show isgoing to be amazing! @robot9$ @robot7%'
# Write the regex
regex = r"@robot\d\W" 

# Find all matches of regex
print("the @robotX are:\n",re.findall(regex, sentiment_analysis))
# Out:
# the @robotX are:
#  ['@robot9!', '@robot4&', '@robot9$', '@robot7%']

# %% [markdown]
# -------------
#
# Extra exersice
#
# -------------
#
# - Write a regex that matches the number of user mentions given as, for example, User_mentions:9 in sentiment_analysis.
#
# - Write a regex that matches the number of likes given as, for example, likes: 5 in sentiment_analysis.
#
# - Write a regex that matches the number of retweets given as, for example, number of retweets: 4 in sentiment_analysis.

# %%
sentiment_analysis = "Unfortunately one of those moments wasn't a giant squid monster. User_mentions:2, likes: 9, number of retweets: 7"

# Write a regex to obtain user mentions
print("Words obtaining 'metions' :\n",re.findall(r"User_mentions\W\d",sentiment_analysis),'\n')

# Write a regex to obtain likes
print("Words obtaining 'likes' : \n",re.findall(r"likes\W\s\d",sentiment_analysis),'\n')

# # Write a regex to obtain number of retweets
print("Words obtaning 'number of retweets :\n",re.findall(r"number\sof\sretweets\W\s\d",sentiment_analysis))
# Out:
# Words obtaining 'metions' :
#  ['User_mentions:2']
#
# Words obtaining 'likes' :
#  ['likes: 9']
#
# Words obtaning 'number of retweets :
#  ['number of retweets: 7']

# %% [markdown]
# --------------
#
# Match and split
#
# ----------------
#
# Some of the tweets in your dataset were downloaded incorrectly. Instead of having spaces to separate words, they have strange characters. You decide to use regular expressions to handle this situation. You print some of these tweets to understand which pattern you need to match.
#
# You notice that the sentences are always separated by a special character, followed by a number, the word break, and after that, another special character, e.g &4break!. The words are always separated by a special character, the word new, and a normal random character, e.g #newH.
#
# -----------------
#
# - Write a regex that matches the pattern separating the sentences in sentiment_analysis, e.g. &4break!.
# - Replace regex_sentence with a space " " in the variable sentiment_analysis. Assign it to sentiment_sub.
# - Write a regex that matches the pattern separating the words in sentiment_analysis, e.g. #newH
# - Replace regex_words with a space in the variable sentiment_sub. Assign it to sentiment_final and print out the result.

# %%
sentiment_analysis = 'He#newHis%newTin love with$newPscrappy. #8break%He is&newYmissing him@newLalready'
print('1.the raw data is:\n',sentiment_analysis,'\n')
# Write a regex to match pattern separating sentences
regex_sentence = r"\W\dbreak\W"

# Replace the regex_sentence with a space
sentiment_sub = re.sub(regex_sentence, " ", sentiment_analysis)
print("2.replace the '#8break%H' with ' ' :\n",sentiment_sub,'\n')

# Write a regex to match pattern separating words
regex_words = r"\Wnew\w"

# Replace the regex_words and print the result
sentiment_final = re.sub(regex_words, " ", sentiment_sub)
print("3.replace the '?new?' with ' ' :\n",sentiment_final,'\n')
# Out:
# 1.the raw data is:
#  He#newHis%newTin love with$newPscrappy. #8break%He is&newYmissing him@newLalready
#
# 2.replace the '#8break%H' with ' ' :
#  He#newHis%newTin love with$newPscrappy.  He is&newYmissing him@newLalready
#
# 3.replace the '?new?' with ' ' :
#  He is in love with scrappy.  He is missing him already

# %% [markdown]
# [2.2]Handle the repetitions of metacharacter
#
# -----------------------
#
# Motivation:
#
# Avoid the cumbersome for using multiple times of single metacharacter.
#
#     example:
#
#     password ="password1234"
#
#     re.search(r"\w\w\w\w\w\w\w\w\d\d\d\d", password)
#
# ------------------------
#
# The Quantifiers
#
# - One times or more: '+'
# - Zero times or more: '*'
# - Zero times or once: '?'
# - Specifier, **n** times at least , **m** times at most : ' {n,m} '

# %% [markdown]
# ------------------
#
# Find out web addresses and user mentions
#
# --------------
#
# - Write a regex to find all the matches of http links appearing in each tweet in sentiment_analysis. Print out the result.
# - Write a regex to find all the matches of user mentions appearing in each tweet in sentiment_analysis. Print out the result.

# %%
sentiment_analysis = ["Boredd. Colddd @blueKnight39 Internet keeps stuffing up. Save me! https://www.tellyourstory.com",
"I had a horrible nightmare last night @anitaLopez98 @MyredHat31 which affected my sleep, now I'm really tired"
"im lonely  keep me company @YourBestCompany! @foxRadio https://radio.foxnews.com 22 female, new york"]


for tweet in sentiment_analysis:
	# Write regex to match http links and print out result
	print('the web address:\n',re.findall(r"https\W+\w+.\w+.\w+", tweet),'\n')

	# Write regex to match user mentions and print out result
	print('the user metion:\n',re.findall(r"@\w+", tweet))
# Out:
# the web address:
#  ['https://www.tellyourstory.com']
#
# the user metion:
#  ['@blueKnight39']
# the web address:
#  ['https://radio.foxnews.com']
#
# the user metion:
#  ['@anitaLopez98', '@MyredHat31', '@YourBestCompany', '@foxRadio']

# %% [markdown]
# --------------------
#
# Find out the datetime elements
#
# --------------------
#
# - Complete the for-loop with a regex that finds all dates in a format similar to 27 minutes ago or 4 hours ago.
# - Complete the for-loop with a regex that finds all dates in a format similar to 23rd june 2018.
# - Complete the for-loop with a regex that finds all dates in a format similar to 1st september 2019 17:25.

# %%
sentiment_analysis = ['I would like to apologize for the repeated Video Games Live related tweets. 32 minutes ago',
'@zaydia but i cant figure out how to get there / back / pay for a hotel 1st May 2019',
'"FML: So much for seniority, bc of technological ineptness 23rd June 2018 17:54"']

# Complete the for-loop with a regex that finds all dates in a format similar to 27 minutes ago or 4 hours ago.
for date in sentiment_analysis:
	print('the terms like "32 minutes ago":\n',re.findall(r"\d{1,2}\s\w+\sago", date),'\n')

# Complete the for-loop with a regex that finds all dates in a format similar to 23rd june 2018.
for date in sentiment_analysis:
	print('the terms like "1st May 2019":\n',re.findall(r"\d{1,2}\w+\s\w+\s\d{4}", date),'\n')

# Complete the for-loop with a regex that finds all dates in a format similar to 1st september 2019 17:25.
for date in sentiment_analysis:
	print('the terms like "23rd June 2018 17:54":\n',re.findall(r"\d{1,2}\w+\s\w+\s\d{4}\s\d{1,2}:\d{2}", date))
# Out:
# the terms like "32 minutes ago":
#  ['32 minutes ago']
#
# the terms like "32 minutes ago":
#  []
#
# the terms like "32 minutes ago":
#  []
#
# the terms like "1st May 2019":
#  []
#
# the terms like "1st May 2019":
#  ['1st May 2019']
#
# the terms like "1st May 2019":
#  ['23rd June 2018']
#
# the terms like "23rd June 2018 17:54":
#  []
# the terms like "23rd June 2018 17:54":
#  []
# the terms like "23rd June 2018 17:54":
#  ['23rd June 2018 17:54']

# %% [markdown]
# -----------------
#
# Tokenize the text
#
# ----------------
#
# - Write a regex that matches the described hashtag pattern. Assign it to the regex variable.
# - Replace all the matches of the regex with an empty string "". Assign it to no_hashtag variable.
# - Split the text in the no_hashtag variable at every match of one or more consecutive whitespace.

# %%
sentiment_analysis = 'ITS NOT ENOUGH TO SAY THAT IMISS U #MissYou #SoMuch #Friendship #Forever'

print('raw text:\n',sentiment_analysis,'\n')
# Write a regex matching the hashtag pattern
regex = r"#\w+"

# Replace the regex by an empty string
no_hashtag = re.sub(regex, "", sentiment_analysis)
print('text without hashtage:\n',no_hashtag,'\n')

# Get tokens by splitting text
print('the tokens:\n',re.split(r"\s+", no_hashtag))
# Out:
# raw text:
#  ITS NOT ENOUGH TO SAY THAT IMISS U #MissYou #SoMuch #Friendship #Forever
#
# text without hashtage:
#  ITS NOT ENOUGH TO SAY THAT IMISS U
#
# the tokens:
#  ['ITS', 'NOT', 'ENOUGH', 'TO', 'SAY', 'THAT', 'IMISS', 'U', '']
